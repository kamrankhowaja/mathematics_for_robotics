# %%
from PIL import Image
image = Image.open("img/coordinate_system.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1070x798>

# %% [markdown]
# Calculate Box Position
#
# $$I_{B} = I_{P} + R_{L} + L_{Q}$$

# %% [markdown]
# ### Robotic Manipulation
#
# Robotic Manipulation involves representing the position and orientation of robot parts and tools in space.
#
# Normally, this represenattion is done using the position and orientation of objects frames in a 3D space.

# %%
from PIL import Image
image = Image.open("img/position_vector.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1110x547>

# %% [markdown]
# ### Description of a frame
#
# A position and an orientation is the information needed to completely specify where the manipulator hand is.
#
# Frame is always defined as $\{B^{A}\} = \{R^{A}_{B}, p^{A}_{Borg}\}$

# %% [markdown]
# #### Mapping Translation Motion Only
# $P^{A} = p^{A}_{Borg} + P^{B}$

# %%
from PIL import Image
image = Image.open("img/translation.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1119x488>

# %%
from PIL import Image
image = Image.open("img/rotation.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1090x502>

# %%
from PIL import Image
image = Image.open("img/rotation_matrix.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1146x610>

# %% [markdown]
# ## General Frames
#
# Assuming that the frame B is both translated and rotated with respect to a base frame A, so the new position of B can per presented in terms of b as:

# %%
from PIL import Image
image = Image.open("img/generalframes.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1118x480>

# %%
## Homogeneous transform 
from PIL import Image
image = Image.open("img/homogeneoustransform.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1142x652>

# %%
from PIL import Image
image = Image.open("img/specialcase.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1122x754>

# %% [markdown]
# ## Transformation Operator
#
# $P^{A}_{2} = T.p^{A}_{1} <==> T^{A}_{B}. P^{B}$

# %% [markdown]
# ## Inverse Transformation

# %%
from PIL import Image
image = Image.open("img/inverse_transform.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1160x688>

# %%
from PIL import Image
image = Image.open("img/eulerstart.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1152x305>

# %%
from PIL import Image
image = Image.open("img/eulerangle.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1147x418>

# %%
from PIL import Image
image = Image.open("img/eulervsfixed.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1139x331>
